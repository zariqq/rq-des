# %%
import pstats

# %%
p = pstats.Stats('sim.prof')
p.strip_dirs().sort_stats('cumtime').print_stats(.01)
# Out:
# Sun Sep 21 12:04:17 2025    sim.prof
#
#          80187067 function calls (79841602 primitive calls) in 64.537 seconds
#
#    Ordered by: cumulative time
#    List reduced from 9505 to 95 due to restriction <0.01>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1   49.865   49.865   63.563   63.563 sim_cp.py:115(run_i_n)
#   6725709    2.907    0.000    7.108    0.000 fromnumeric.py:1349(argmin)
#   6725709    1.553    0.000    4.202    0.000 fromnumeric.py:51(_wrapfunc)
#  13451418    2.492    0.000    3.144    0.000 sim_cp.py:10(set_one)
#   6725709    2.074    0.000    2.074    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#         3    0.000    0.000    1.763    0.588 dispatcher.py:344(_compile_for_args)
#      39/3    0.000    0.000    1.753    0.584 dispatcher.py:862(compile)
#      13/3    0.000    0.000    1.753    0.584 dispatcher.py:79(compile)
#      13/3    0.000    0.000    1.753    0.584 dispatcher.py:86(_compile_cached)
# ...

# %%
p = pstats.Stats('sim_jit.prof')
p.strip_dirs().sort_stats('tottime').print_stats(.01)
# Out:
# Sun Sep 21 12:15:16 2025    sim_jit.prof
#
#          12764774 function calls (12056418 primitive calls) in 5.268 seconds
#
#    Ordered by: internal time
#    List reduced from 9849 to 98 due to restriction <0.01>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     31260    0.944    0.000    1.252    0.000 ffi.py:195(__call__)
#     80/74    0.223    0.003    0.226    0.003 {built-in method _imp.create_dynamic}
#      1390    0.202    0.000    0.202    0.000 {method 'read' of '_io.BufferedReader' objects}
#   2229218    0.167    0.000    0.193    0.000 {built-in method builtins.isinstance}
# 264049/46366    0.145    0.000    0.228    0.000 ir.py:321(_rec_list_vars)
# 214541/97444    0.083    0.000    0.266    0.000 {method 'format' of 'str' objects}
#    193370    0.082    0.000    0.161    0.000 event.py:243(notify)
#      1390    0.073    0.000    0.073    0.000 {built-in method marshal.loads}
# ...

# %%
p = pstats.Stats("sim.prof")
p.strip_dirs().sort_stats("cumtime").print_stats(0.01)
# Out:
# Sun Sep 21 13:42:39 2025    sim.prof
#
#          13593592 function calls (12850199 primitive calls) in 5.885 seconds
#
#    Ordered by: cumulative time
#    List reduced from 9601 to 96 due to restriction <0.01>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    4.414    4.414 dispatcher.py:344(_compile_for_args)
#     301/1    0.002    0.000    4.403    4.403 dispatcher.py:862(compile)
#      61/1    0.000    0.000    4.403    4.403 dispatcher.py:79(compile)
#      61/1    0.000    0.000    4.403    4.403 dispatcher.py:86(_compile_cached)
#      61/1    0.001    0.000    4.403    4.403 dispatcher.py:101(_compile_core)
#      61/1    0.000    0.000    4.403    4.403 compiler.py:713(compile_extra)
#  2292/275    0.003    0.000    4.135    0.015 compiler_lock.py:32(_acquire_compile_lock)
#      64/1    0.000    0.000    4.058    4.058 compiler.py:433(compile_extra)
# ...

# %%
from sim_cp import run_i_n

# %%
run_i_n.inspect_asm()
# Out:
# {(int64,
#   omitted(default=np.float64(0.8)),
#   omitted(default=np.float64(2.0)),
#   omitted(default=np.float64(1.0)),
#   omitted(default=np.float64(0.08)),
# ...
